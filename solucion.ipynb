# %% [markdown]
# # Examen Parcial - Programación

# %% [markdown]
# <div class="alert alert-info"><strong>Reglas del examen:</strong>
#
# 1. El examen es personal, se puede acceder a internet pero nada de celulares.
# 2. Se utilizará la plataforma de Colab y se guardará como *.ipynb con su nombre con el siguiente formato: ApellidoPaterno_PrimerNombre_Codigo, por ejemplo:  Yali_Roy_10160215.
# 3. Una vez terminado el examen, subirlo a la siguiente ruta: **shorturl.at/ayCF6**
#
# </div>

# %% [markdown]
# ## Nivel 1 (2 ptos c/u)

# %% [markdown]
# 1. Devuelva el factorial de un número x.

# %%
# correcto
import math
x = 5
print(math.factorial(x))
# Out:
# 120

# %%
def factorial(n):
  if(n==0 or n==1):
         resultado=1
  elif n>=1:
         resultado=n*factorial(n-1)
  return resultado
factorial=factorial(8)
print("el valor hallado es:",factorial)
# Out:
# el valor hallado es: 40320

# %% [markdown]
# 2. Determinar si un año es bisiesto, ingresando el año.

# %%
def año(n):
  x=n/4
  if type(x) is int :
       print("no es bisiesto")
  elif type(x) is float:
      print("es año bisiesto")
año(2012)
# Out:
# es año bisiesto

# %% [markdown]
# 3. Realizar una función que devuelva el volumen de una esfera a partir de su radio.

# %%
print("volumen de la esfera")
print("v=(4*pi*r**3)/3")
r=float(input("r="))

from math import pi
volumen=((4*pi*r**3)/3)
print("el volumen es",volumen)

# %%
r= float(input("radio es:"))
import math
def volumen_esfera(r):
  volumen_esfera=(4/3)*math.pi*r**3
  return volumen_esfera
volumen_esfera(r)

# %%
r=float(input("r="))

from math import pi
volumen=((4*pi*r**3)/3)
print("el volumen es",volumen)
# Out:
# a=5
# el volumen es 523.5987755982989

# %% [markdown]
# 4. Realizar una función que devuelva lo siguiente, utilizando iteradores:
#     * * * * *
#     * * * *
#     * * *
#     * *
#     * *
#     * * *
#     * * * *
#     * * * * *

# %%
#CORRECTA:

for x in range (5,1,-1):
   print("* "*x)
    
for y in range (2,6,1):
   print("* "*y)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# * *
# * * *
# * * * *
# * * * * *

# %%
for x in range (7,1,-2):
    print("/"*x)
# Out:
# ///////
# /////
# ///

# %% [markdown]
# ***
# ***
# ***
#   * *
#   * *
# ***
# ***
# ***

# %% [markdown]
# 5. Ingresar grados en numero decimal y devuelva como string con minutos y segundos. (p.e. 73° 25' 44")

# %%
x=float(input("ingresar grados "))
g=int(x)
m=int((x-g)*60)
s=round((((x-g)*60)-m)*60)
print("los valores son:",str(g)+"°" + str(m)+"'" + str(s)+"''")
# Out:
# ingresar grados 12.3456
# los valores son: 12°20'44''

# %% [markdown]
# ## Nivel 2 (3 ptos c/u)

# %% [markdown]
# 6. Ordena la lista [(2,5), (1,2), (4,4), (2,3), (2,1)] por el segundo elemento de cada tupla.

# %%
def last(n):return n[1]
def sort_list_last(tuples):
   return sorted(tuples, key=last)
print(sort_list_last([(2,5), (1,2), (4,4), (2,3), (2,1)]))
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %% [markdown]
# 7. Realizar una función que pida la longitud de los tres lados de un triángulo y escriba si el triángulo existe o no; en caso exista, devuelva su área.

# %%
def triangulo(a,b,c):
  if a+b>c and a+c>b and b+c>a :
     print("existe")
  else:
    print("no existe")
triangulo(2,5,8)
# Out:
# existe
# existe

# %%
def triangulo(a,b,c):
  if a+b>c and a+c>b and b+c>a :
     print("existe")
  else:
    print("no existe")
triangulo(90,1,1)
# Out:
# no existe

# %% [markdown]
# 8. Leer el archivo "ubigeos.json" y realizar una función en la que ingresando el ubigeo, devuelva el nombre del departamento, provincia y distrito.

# %%
import json
archivo = open("ubigeos.json","r")
leer = archivo.read()
python = json.loads(leer)
print(python)

ubigeo = input("ingrese ubigeo: ")
print(python[ubigeo]["DEPARTAMENTO"],python[ubigeo]["PROVINCIA"],python[ubigeo]["DISTRITO"])
# Out:
# {'010101': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHACHAPOYAS', 'PROVINCIA': 'CHACHAPOYAS'}, '010102': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'ASUNCION', 'PROVINCIA': 'CHACHAPOYAS'}, '010103': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'BALSAS', 'PROVINCIA': 'CHACHAPOYAS'}, '010104': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHETO', 'PROVINCIA': 'CHACHAPOYAS'}, '010105': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHILIQUIN', 'PROVINCIA': 'CHACHAPOYAS'}, '010106': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHUQUIBAMBA', 'PROVINCIA': 'CHACHAPOYAS'}, '010107': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'GRANADA', 'PROVINCIA': 'CHACHAPOYAS'}, '010108': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'HUANCAS', 'PROVINCIA': 'CHACHAPOYAS'}, '010109': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'LA JALCA', 'PROVINCIA': 'CHACHAPOYAS'}, '010110': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'LEIMEBAMBA', 'PROVINCIA': 'CHACHAPOYAS'}, '010111': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'LEVANTO', 'PROVINCIA': 'CHACHAPOYAS'}, '010112': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'MAGDALENA', 'PROVINCIA': 'CHACHAPOYAS'}, '010113': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'MARISCAL CASTILLA', 'PROVINCIA': 'CHACHAPOYAS'}, '010114': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'MOLINOPAMPA', 'PROVINCIA': 'CHACHAPOYAS'}, '010115': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'MONTEVIDEO', 'PROVINCIA': 'CHACHAPOYAS'}, '010116': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'OLLEROS', 'PROVINCIA': 'CHACHAPOYAS'}, '010117': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'QUINJALCA', 'PROVINCIA': 'CHACHAPOYAS'}, '010118': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SAN FRANCISCO DE DAGUAS', 'PROVINCIA': 'CHACHAPOYAS'}, '010119': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SAN ISIDRO DE MAINO', 'PROVINCIA': 'CHACHAPOYAS'}, '010120': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SOLOCO', 'PROVINCIA': 'CHACHAPOYAS'}, '010121': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SONCHE', 'PROVINCIA': 'CHACHAPOYAS'}, '010201': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'BAGUA', 'PROVINCIA': 'BAGUA'}, '010202': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'ARAMANGO', 'PROVINCIA': 'BAGUA'}, '010203': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'COPALLIN', 'PROVINCIA': 'BAGUA'}, '010204': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'EL PARCO', 'PROVINCIA': 'BAGUA'}, '010205': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'IMAZA', 'PROVINCIA': 'BAGUA'}, '010206': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'LA PECA', 'PROVINCIA': 'BAGUA'}, '010301': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'JUMBILLA', 'PROVINCIA': 'BONGARA'}, '010302': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHISQUILLA', 'PROVINCIA': 'BONGARA'}, '010303': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CHURUJA', 'PROVINCIA': 'BONGARA'}, '010304': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'COROSHA', 'PROVINCIA': 'BONGARA'}, '010305': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CUISPES', 'PROVINCIA': 'BONGARA'}, '010306': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'FLORIDA', 'PROVINCIA': 'BONGARA'}, '010307': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'JAZAN', 'PROVINCIA': 'BONGARA'}, '010308': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'RECTA', 'PROVINCIA': 'BONGARA'}, '010309': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SAN CARLOS', 'PROVINCIA': 'BONGARA'}, '010310': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'SHIPASBAMBA', 'PROVINCIA': 'BONGARA'}, '010311': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'VALERA', 'PROVINCIA': 'BONGARA'}, '010312': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'YAMBRASBAMBA', 'PROVINCIA': 'BONGARA'}, '010401': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'NIEVA', 'PROVINCIA': 'CONDORCANQUI'}, '010402': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'EL CENEPA', 'PROVINCIA': 'CONDORCANQUI'}, '010403': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'RIO SANTIAGO', 'PROVINCIA': 'CONDORCANQUI'}, '010501': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'LAMUD', 'PROVINCIA': 'LUYA'}, '010502': {'DEPARTAMENTO': 'AMAZONAS', 'DISTRITO': 'CAMPORREDONDO', 'PROVINCIA': 'LUYA'}, '010503': {' ...
# ingrese ubigeo: 010101
# AMAZONAS CHACHAPOYAS CHACHAPOYAS

# %% [markdown]
# 9. Realice una función que calcule la pendiente entre dos puntos, teniendo las coordenadas.

# %%
def pendiente(x1,x2,y1,y2):
    m=((y2-y1)/(x2-x1))
    return("la pendiente de la recta es: {} ".format(m))
pendiente(4,5,6,7)
# Out:
# 'la pendiente de la recta es: 1.0 '

# %%
def pendiente(x1,x2,y1,y2):
    m=((y2-y1)/(x2-x1))
    return("la pendiente de la recta es:",m)
pendiente(4,5,6,7)
# Out:
# ('la pendiente de la recta es:', 1.0)

# %% [markdown]
# 10. Desarrollar una función que pueda calcular la sumatoria para n números:
#
#     $1^2 + 2^2 + 3^2 + . . . +  n^2$

# %%
X = 0
for n in range(3):
    X += (n+1)**2
print(X)
# Out:
# 14

# %%
def cuadrado(n):
    x = (((n*(n+1)*((2*n)+1)))/6)
    return("la suma de cuadrados es",x)
cuadrado(3)
# Out:
# ('la suma de cuadrados es', 14.0)

# %% [markdown]
# ## Nivel 3 (4 ptos c/u)

# %% [markdown]
# 11. Leer el archivo "departamentos.json" y realizar una función en la que ingresando el nombre del departamento, devuelva la cantidad de provincias y distritos.

# %%
import json
archivo = open("departamentos.json","r")
leer1 = archivo.read()
python1 = json.loads(leer1)
print(python1)

DEPARTAMENTO = input("nombre del departamento: ")
print(python1[DEPARTAMENTO]["PROVINCIA"])
# Out:
# {'AMAZONAS': {'DISTRITO': 'YAMON', 'PROVINCIA': 'UTCUBAMBA'}, 'ANCASH': {'DISTRITO': 'YANAMA', 'PROVINCIA': 'YUNGAY'}, 'APURIMAC': {'DISTRITO': 'CURASCO', 'PROVINCIA': 'GRAU'}, 'AREQUIPA': {'DISTRITO': 'TORO', 'PROVINCIA': 'LA UNION'}, 'AYACUCHO': {'DISTRITO': 'VISCHONGO', 'PROVINCIA': 'VILCAS HUAMAN'}, 'CAJAMARCA': {'DISTRITO': 'YAUYUCAN', 'PROVINCIA': 'SANTA CRUZ'}, 'CALLAO': {'DISTRITO': 'MI PERU', 'PROVINCIA': 'CALLAO'}, 'CUSCO': {'DISTRITO': 'YUCAY', 'PROVINCIA': 'URUBAMBA'}, 'HUANCAVELICA': {'DISTRITO': 'SANTIAGO DE TUCUMA', 'PROVINCIA': 'TAYACAJA'}, 'HUANUCO': {'DISTRITO': 'CHORAS', 'PROVINCIA': 'YAROWILCA'}, 'ICA': {'DISTRITO': 'TUPAC AMARU INCA', 'PROVINCIA': 'PISCO'}, 'JUNIN': {'DISTRITO': 'YANACANCHA', 'PROVINCIA': 'CHUPACA'}, 'LALIBERTAD': {'DISTRITO': 'GUADALUPITO', 'PROVINCIA': 'VIRU'}, 'LAMBAYEQUE': {'DISTRITO': 'TUCUME', 'PROVINCIA': 'LAMBAYEQUE'}, 'LIMA': {'DISTRITO': 'VITIS', 'PROVINCIA': 'YAUYOS'}, 'LORETO': {'DISTRITO': 'YAGUAS', 'PROVINCIA': 'PUTUMAYO'}, 'MADRE DE DIOS': {'DISTRITO': 'TAHUAMANU', 'PROVINCIA': 'TAHUAMANU'}, 'MOQUEGUA': {'DISTRITO': 'PACOCHA', 'PROVINCIA': 'ILO'}, 'PASCO': {'DISTRITO': 'CONSTITUCION', 'PROVINCIA': 'OXAPAMPA'}, 'PIURA': {'DISTRITO': 'RINCONADA LLICUAR', 'PROVINCIA': 'SECHURA'}, 'PUNO': {'DISTRITO': 'UNICACHI', 'PROVINCIA': 'YUNGUYO'}, 'SAN MARTIN': {'DISTRITO': 'UCHIZA', 'PROVINCIA': 'TOCACHE'}, 'TACNA': {'DISTRITO': 'TICACO', 'PROVINCIA': 'TARATA'}, 'TUMBES': {'DISTRITO': 'PAPAYAL', 'PROVINCIA': 'ZARUMILLA'}, 'UCAYALI': {'DISTRITO': 'PURUS', 'PROVINCIA': 'PURUS'}}
# nombre del departamento: AMAZONAS
# YAMON

# %% [markdown]
# tengo la respuesta pero np la entedi

# %%
departamento = input("nombre del departamento: ")
print(python[ubigeo]["DEPARTAMENTO"],python[ubigeo]["PROVINCIA"],python[ubigeo]["DISTRITO"])
